# %%
import numpy as np
from scipy import fftpack
import tensorly as tl
from util import square_tensor_gen, TensorInfoBucket, RandomInfoBucket, eval_mse, eval_rerr
from sketch import Sketch
import time
from tensorly.decomposition import tucker
from sketch_recover import SketchTwoPassRecover
from sketch_recover import SketchOnePassRecover
import matplotlib 
import matplotlib.pyplot as plt
from simulation import Simulation
plt.style.use('fivethirtyeight')
# %matplotlib inline
# Out:
# Using mxnet backend.
# /Users/apple/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /Users/apple/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py:46: DeprecationWarning: OpenSSL.rand is deprecated - you should use os.urandom instead
#   import OpenSSL.SSL
# Using numpy backend.

# %%
gen_types = ['id', 'id1', 'id2', 'spd', 'fpd', 'sed', 'fed', 'lk']
rs = [1,5]
dim = 3

# %%
def plot_row(gen_type,r,noise_level,name, ns = np.arange(100,201,100), dim = 3, sim_runs = 1):
    plt.close()
    plt.figure(figsize = (len(ns)*5,5))
    for plot_id, n in enumerate(ns): 
        random_seed = np.random.randint(1000000) 
        ks =np.arange(r, int(n/2),int(n/20)) 
        ho_svd_rerr = np.zeros(len(ks))
        two_pass_rerr = np.zeros(len(ks))
        one_pass_rerr = np.zeros(len(ks))
        for idx, k in enumerate(ks): 
            simu = Simulation(np.repeat(n,dim), r, k, 2*k, RandomInfoBucket(random_seed), gen_type, noise_level)
            _, rerr = simu.ho_svd()
            ho_svd_rerr[idx] = rerr 
            _, rerr = simu.two_pass() 
            two_pass_rerr[idx] = rerr
            _, rerr = simu.one_pass()
            one_pass_rerr[idx] = rerr 
        print(ho_svd_rerr)
        print(two_pass_rerr)
        print(one_pass_rerr)
        plt.subplot(1,len(ns),plot_id+1) 
        plt.plot(two_pass_rerr, ks**dim+ks*dim*n, label = 'two_pass')
        plt.title('two_pass')
        plt.plot(one_pass_rerr, (2*ks)**dim + ks*dim*n, label = 'one_pass') 
        plt.title('one_pass') 
        plt.plot(ho_svd_rerr, ks**dim + ks*dim*n, label = 'hosvd') 
        plt.title('hosvd') 
        plt.legend(loc = 'best')
        plt.title("n = %s"%(n))
        plt.xlabel('Relative Error')
        plt.ylabel('log(Storage)')
        plt.yscale('log')
        plt.axis('equal')
        ymin, ymax = plt.ylim()  
        plt.ylim((ymin, ymax)) 
        xmin, xmax = plt.xlim()  
        plt.xlim((xmin, xmax))   
    plt.tight_layout()
    plt.savefig('plots/'+name)
    plt.show()

# %%
plot_row('id',5,0.01,"id_lnoise_storage.pdf",ns = np.arange(100,301,100), sim_runs = 1)
# Out:
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# ...

# %%
plot_row('id',5,0,"id_nonoise_storage.pdf",ns = np.arange(100,301,100), sim_runs = 1)
# Out:
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# ...

# %%
plot_row('id',5,1,"id_hnoise_storage.pdf",ns = np.arange(100,301,100), sim_runs = 1)
# Out:
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# ...

# %%
plot_row('id',1,0.01,"id_rk1_storage.pdf",ns = np.arange(100,301,100), sim_runs = 1)
# Out:
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# ...

# %%
plot_row('spd',5,0.01,"spd_storage.pdf",ns = np.arange(100,301,100), sim_runs = 1)
# Out:
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# ...

# %%
plot_row('fpd',5,0.01,"fpd_storage.pdf",ns = np.arange(100,301,100), sim_runs = 1)
# Out:
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# ...

# %%
plot_row('sed',5,0.01,"sed_storage.pdf",ns = np.arange(100,301,100), sim_runs = 1)
# Out:
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# ...

# %%
plot_row('fed',5,0.01,"fed_storage.pdf",ns = np.arange(100,301,100), sim_runs = 1)
# Out:
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# Using numpy backend.
# ...
